# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/worldcup-2018.csv')
df
# df.info()
# Shift + Tab
# Out:
#             Team Group  Previous \nappearances  Previous \ntitles  \
# 0         Russia     A                      10                  0
# 1   Saudi Arabia     A                       4                  0
# 2          Egypt     A                       2                  0
# 3        Uruguay     A                      12                  2
# 4        Porugal     B                       6                  0
# 5          Spain     B                      14                  1
# 6        Morocco     B                       4                  0
# 7           IRAN     B                       4                  0
# 8         France     C                      14                  1
# 9      Australia     C                       4                  0
# 10          Peru     C                       4                  0
# 11       Denmark     C                       4                  0
# 12     Argentina     D                      16                  2
# ...

# %%
df.head()
# Out:
#              0      1                       2                  3   \
# 0          Team  Group  Previous \nappearances  Previous \ntitles
# 1        Russia      A                      10                  0
# 2  Saudi Arabia      A                       4                  0
# 3         Egypt      A                       2                  0
# 4       Uruguay      A                      12                  2
#
#                   4                      5                    6   \
# 0  Previous\n finals  Previous\n semifinals  Current \nFIFA rank
# 1                  0                      1                   65
# 2                  0                      0                   63
# 3                  0                      0                   31
# 4                  2                      5                   21
#
#                       7            8                                    9   \
# 0  First match \nagainst  Match index  history with \nfirst opponent\n W-L
# ...

# %%
df.head(3)
# Out:
#            Team Group  Previous \nappearances  Previous \ntitles  \
# 0        Russia     A                      10                  0
# 1  Saudi Arabia     A                       4                  0
# 2         Egypt     A                       2                  0
#
#    Previous\n finals  Previous\n semifinals  Current \nFIFA rank  \
# 0                  0                      1                   65
# 1                  0                      0                   63
# 2                  0                      0                   31
#
#   First match \nagainst  Match index  history with \nfirst opponent\n W-L  \
# 0          Saudi Arabia            1                                 -1.0
# 1                Russia            1                                  1.0
# 2               Uruguay            2                                 -1.0
#
#    history with\n first opponent\n goals Second match\n against  \
# 0                                   -2.0                  Egypt
# ...
