# %%
vgsales <- read.csv("vgsales.csv")

# %%
vgsales
# Out:
#       Rank  Name
# 1      1    Wii Sports
# 2      2    Super Mario Bros.
# 3      3    Mario Kart Wii
# 4      4    Wii Sports Resort
# 5      5    Pokemon Red/Pokemon Blue
# 6      6    Tetris
# 7      7    New Super Mario Bros.
# 8      8    Wii Play
# 9      9    New Super Mario Bros. Wii
# 10    10    Duck Hunt
# 11    11    Nintendogs
# 12    12    Mario Kart DS
# 13    13    Pokemon Gold/Pokemon Silver
# 14    14    Wii Fit
# 15    15    Wii Fit Plus
# 16    16    Kinect Adventures!
# 17    17    Grand Theft Auto V
# 18    18    Grand Theft Auto: San Andreas
# 19    19    Super Mario World
# 20    20    Brain Age: Train Your Brain in Minutes a Day
# 21    21    Pokemon Diamond/Pokemon Pearl
# 22    22    Super Mario Land
# 23    23    Super Mario Bros. 3
# 24    24    Grand Theft Auto V
# 25    25    Grand Theft Auto: Vice City
# 26    26    Pokemon Ruby/Pokemon Sapphire
# 27    27    Pokemon Black/Pokemon White
# 28    28    Brain Age 2: More Training in Minutes a Day
# ...

# %%
# Basic scatterplot
by_platform = group_by(vgsales, Platform)
by_platform = summarise(by_platform, sum(Global_Sales))
# Out:
#    Platform sum(Global_Sales)
# 1  2600       97.08
# 2  3DO         0.10
# 3  3DS       247.46
# 4  DC         15.97
# 5  DS        822.49
# 6  GB        255.45
# 7  GBA       318.50
# 8  GC        199.36
# 9  GEN        28.36
# 10 GG          0.04
# 11 N64       218.88
# 12 NES       251.07
# 13 NG          1.44
# 14 PC        258.82
# 15 PCFX        0.03
# 16 PS        730.66
# 17 PS2      1255.64
# 18 PS3       957.84
# 19 PS4       278.10
# 20 PSP       296.28
# 21 PSV        61.93
# 22 SAT        33.59
# 23 SCD         1.87
# 24 SNES      200.05
# 25 TG16        0.16
# 26 Wii       926.71
# 27 WiiU       81.86
# 28 WS          1.42
# 29 X360      979.96
# 30 XB        258.26
# 31 XOne      141.06

# %%
library(ggplot2)
ggplot(data= by_platform, aes(y=Platform, x= (Global_Sales)) )+
  geom_point()
# Out:
# plot without title

# %%
library(dplyr) 
group_by(vgsales, Platform)
# Out:
#       Rank  Name
# 1      1    Wii Sports
# 2      2    Super Mario Bros.
# 3      3    Mario Kart Wii
# 4      4    Wii Sports Resort
# 5      5    Pokemon Red/Pokemon Blue
# 6      6    Tetris
# 7      7    New Super Mario Bros.
# 8      8    Wii Play
# 9      9    New Super Mario Bros. Wii
# 10    10    Duck Hunt
# 11    11    Nintendogs
# 12    12    Mario Kart DS
# 13    13    Pokemon Gold/Pokemon Silver
# 14    14    Wii Fit
# 15    15    Wii Fit Plus
# 16    16    Kinect Adventures!
# 17    17    Grand Theft Auto V
# 18    18    Grand Theft Auto: San Andreas
# 19    19    Super Mario World
# 20    20    Brain Age: Train Your Brain in Minutes a Day
# 21    21    Pokemon Diamond/Pokemon Pearl
# 22    22    Super Mario Land
# 23    23    Super Mario Bros. 3
# 24    24    Grand Theft Auto V
# 25    25    Grand Theft Auto: Vice City
# 26    26    Pokemon Ruby/Pokemon Sapphire
# 27    27    Pokemon Black/Pokemon White
# 28    28    Brain Age 2: More Training in Minutes a Day
# ...

# %%
vgsales
# Out:
#       Rank  Name
# 1      1    Wii Sports
# 2      2    Super Mario Bros.
# 3      3    Mario Kart Wii
# 4      4    Wii Sports Resort
# 5      5    Pokemon Red/Pokemon Blue
# 6      6    Tetris
# 7      7    New Super Mario Bros.
# 8      8    Wii Play
# 9      9    New Super Mario Bros. Wii
# 10    10    Duck Hunt
# 11    11    Nintendogs
# 12    12    Mario Kart DS
# 13    13    Pokemon Gold/Pokemon Silver
# 14    14    Wii Fit
# 15    15    Wii Fit Plus
# 16    16    Kinect Adventures!
# 17    17    Grand Theft Auto V
# 18    18    Grand Theft Auto: San Andreas
# 19    19    Super Mario World
# 20    20    Brain Age: Train Your Brain in Minutes a Day
# 21    21    Pokemon Diamond/Pokemon Pearl
# 22    22    Super Mario Land
# 23    23    Super Mario Bros. 3
# 24    24    Grand Theft Auto V
# 25    25    Grand Theft Auto: Vice City
# 26    26    Pokemon Ruby/Pokemon Sapphire
# 27    27    Pokemon Black/Pokemon White
# 28    28    Brain Age 2: More Training in Minutes a Day
# ...
